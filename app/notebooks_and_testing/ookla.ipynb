# %%
# install.packages("remotes")
# library(remotes)
# remotes::install_github("teamookla/ooklaOpenDataR")

# %%
library(tidyverse)
library(ooklaOpenDataR)
library(tigris)
library(sf)
# Out:
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.1 ──
#
# ✔ ggplot2 3.3.5     ✔ purrr   1.0.1
# ✔ tibble  3.1.7     ✔ dplyr   1.0.9
# ✔ tidyr   1.2.0     ✔ stringr 1.5.0
# ✔ readr   2.1.2     ✔ forcats 0.5.1
#
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
#
# To enable caching of data, set `options(tigris_use_cache = TRUE)`
# in your R script or .Rprofile.
#
# Linking to GEOS 3.10.2, GDAL 3.4.3, PROJ 8.2.0; sf_use_s2() is TRUE

# %%
data <- get_performance_tiles("fixed", 2022, 4)
# Out:
# Downloading data from 's3://ookla-open-data/parquet/performance/type=fixed/year=2022/quarter=4/2022-10-01_performance_fixed_tiles.parquet'...

# %%
counties <- c('Asotin', 'Lincoln', 'Ferry', 'Garfield', 'Pend Oreille', 'Stevens', 'Whitman', 'Spokane',
    'Adams')

wa_tracts <- tigris::tracts(state = "Washington", county = counties) %>% 
    select(state_code = STATEFP, geoid = GEOID, tract = NAME) %>% 
    st_transform(4326)

# %%
head(wa_tracts)
# Out:
# Registered S3 method overwritten by 'geojsonsf':
#   method        from
#   print.geojson geojson
#
# Warning message in fun(libname, pkgname):
# “rgeos: versions of GEOS runtime 3.10.2-CAPI-1.16.0
# and GEOS at installation 3.8.0-CAPI-1.13.1differ”
#    STATEFP COUNTYFP TRACTCE GEOID       NAME   NAMELSAD            MTFCC
# 14 53      075      000602  53075000602 6.02   Census Tract 6.02   G5020
# 15 53      075      000601  53075000601 6.01   Census Tract 6.01   G5020
# 16 53      075      000202  53075000202 2.02   Census Tract 2.02   G5020
# 17 53      075      000201  53075000201 2.01   Census Tract 2.01   G5020
# 53 53      063      011702  53063011702 117.02 Census Tract 117.02 G5020
# 54 53      063      014400  53063014400 144    Census Tract 144    G5020
#    FUNCSTAT ALAND     AWATER INTPTLAT    INTPTLON
# 14 S         83019278      0 +46.7712346 -117.0989449
# 15 S          1028996      0 +46.7414143 -117.1645509
# 16 S          2019222      0 +46.7387186 -117.1853588
# 17 S        107067961      0 +46.7943975 -117.2247486
# 53 S          7157584 205845 +47.6819109 -117.2370346
# 54 S          6308443  25162 +47.6933186 -117.3521333
#    geometry
# 14 MULTIPOLYGON (((-117.1716 4...
# 15 MULTIPOLYGON (((-117.1728 4...
# 16 MULTIPOLYGON (((-117.1965 4...
# 17 MULTIPOLYGON (((-117.3252 4...
# 53 MULTIPOLYGON (((-117.272 47...
# 54 MULTIPOLYGON (((-117.3639 4...

# %%
tile_data <- st_join(wa_tracts, data, left = FALSE)
# Out:
# Error in st_join.sf(wa_tracts, data, left = FALSE): second argument should be of class sf: maybe revert the first two arguments?
# Traceback:
#
# 1. st_join(wa_tracts, data, left = FALSE)
# 2. st_join.sf(wa_tracts, data, left = FALSE)
# 3. stop("second argument should be of class sf: maybe revert the first two arguments?")
