# %%
library(tidyverse)

provider_data <- read.csv("../data/provider_data.csv")
# Out:
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.1 ──
#
# ✔ ggplot2 3.4.0     ✔ purrr   1.0.1
# ✔ tibble  3.1.7     ✔ dplyr   1.0.9
# ✔ tidyr   1.2.0     ✔ stringr 1.5.0
# ✔ readr   2.1.2     ✔ forcats 0.5.1
#
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()

# %%
provider_data %>% 
    filter(provider_id == 79497)
# Out:
#       X      tract  company    is_consumer is_business max_d_mbps max_u_mbps
# 1       4      6.02 Viasat Inc 1           1           100        3
# 2      15      6.02 Viasat Inc 1           1           100        3
# 3      19      6.02 Viasat Inc 1           1           100        3
# 4      28      6.02 Viasat Inc 1           1           100        3
# 5      39      6.02 Viasat Inc 1           1           100        3
# 6      49      6.02 Viasat Inc 1           1           100        3
# 7      55      6.01 Viasat Inc 1           1           100        3
# 8      67      6.01 Viasat Inc 1           1           100        3
# 9      71      6.01 Viasat Inc 1           1           100        3
# 10     78      6.01 Viasat Inc 1           1           100        3
# 11     92      6.01 Viasat Inc 1           1           100        3
# 12    106      2.02 Viasat Inc 1           1           100        3
# 13    111      2.02 Viasat Inc 1           1           100        3
# ...

# %%
unique_providers <- provider_data %>% 
    filter(is_consumer == 1) %>% 
    select(provider_id, company) %>% 
    unique()

# %%
# write.csv(unique_providers, "../data/unique_providers.csv")
