# %% [markdown]
# # PCA - Method 1

# %% [markdown]
# ## Get the data

# %%
import pandas as pd

# %%
# import the standardized data into a dataframe
data = pd.read_csv("../data/standardized_data.csv")

# %%
# view top 5 rows of the data
data.head()
# Out:
#          GEOID    tract  not_citizen  naturalized_citizen  native_citizen  \
# 0  53001950100  9501.00    -0.482364            -0.136075       -0.777232
# 1  53001950200  9502.00     0.087773            -1.067185       -1.423574
# 2  53001950301  9503.01     2.028432            -0.818167       -1.843209
# 3  53001950302  9503.02     2.494409             0.946610       -1.389043
# 4  53001950303  9503.03     2.351875             0.232038       -1.259924
#
#    foreign_born  work_from_home  desktop_or_laptop  desktop_or_laptop_only  \
# 0     -0.423714       -0.510108          -0.880685                0.078368
# 1     -0.347869       -0.865321          -1.483304               -1.169515
# 2      1.240681       -1.311874          -1.888989               -1.244016
# 3      2.285668       -1.078448          -1.764920               -1.560643
# 4      1.898011       -0.225938          -1.585710               -1.448892
#
# ...

# %%
# remove the columns that I don't want (geoid, tract)
data = data.drop(columns=["GEOID", "tract"])
data.head()
# Out:
#    not_citizen  naturalized_citizen  native_citizen  foreign_born  \
# 0    -0.482364            -0.136075       -0.777232     -0.423714
# 1     0.087773            -1.067185       -1.423574     -0.347869
# 2     2.028432            -0.818167       -1.843209      1.240681
# 3     2.494409             0.946610       -1.389043      2.285668
# 4     2.351875             0.232038       -1.259924      1.898011
#
#    work_from_home  desktop_or_laptop  desktop_or_laptop_only  smartphone  \
# 0       -0.510108          -0.880685                0.078368   -0.734196
# 1       -0.865321          -1.483304               -1.169515   -1.434819
# 2       -1.311874          -1.888989               -1.244016   -1.823626
# 3       -1.078448          -1.764920               -1.560643   -1.336655
# 4       -0.225938          -1.585710               -1.448892   -1.284685
#
#    smartphone_only  tablet_or_portable  ...  access_with_no_subscription  \
# ...
