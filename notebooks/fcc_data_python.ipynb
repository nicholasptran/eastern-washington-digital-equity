# %%
import pandas as pd

# %%
COUNTIES = (1, 3, 19, 23, 43, 51, 63, 65, 75)
wa_data = pd.read_csv("../data/Washington.csv")
wa_data = wa_data[wa_data.county.isin(COUNTIES)]
wa_data.head()
# Out:
#    state  county     cnamelong   tract  tractname  block    tractcode  \
# 0     53       1  Adams County  950100     9501.0   1000  53001950100
# 1     53       1  Adams County  950100     9501.0   1001  53001950100
# 2     53       1  Adams County  950100     9501.0   1002  53001950100
# 3     53       1  Adams County  950100     9501.0   1003  53001950100
# 4     53       1  Adams County  950100     9501.0   1004  53001950100
#
#          blockcode
# 0  530019501001000
# 1  530019501001001
# 2  530019501001002
# 3  530019501001003
# 4  530019501001004

# %%
data = pd.read_csv("https://opendata.fcc.gov/resource/jdr4-3q4p.csv")
data = data[data.stateabbr.isin(["WA"])]
data.head()
# Out:
#      logrecno  provider_id       frn                          providername  \
# 62   10182049        77036  14694327                       STARTOUCH, INC.
# 74   76453809        76178  18756155                    VSAT Systems, LLC.
# 87   76360342        81097  12369286                  HNS License Sub, LLC
# 100  29092914        79497   4963088                          ViaSat, Inc.
# 118  38338812        81199  26043968  Space Exploration Technologies Corp.
#
#                                   dbaname  \
# 62                        StarTouch, Inc.
# 74                         VSATSystemsLLC
# 87                              HughesNet
# 100                            Viasat Inc
# 118  Space Exploration Technologies Corp.
#
#                        holdingcompanyname  hoconum  \
# 62                        STARTOUCH, INC.   190342
# 74                     VSAT Systems, LLC.   300167
# 87                   DishNET Holding, LLC   130627
# ...
