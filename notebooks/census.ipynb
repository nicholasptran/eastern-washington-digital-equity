# %%
import pandas as pd
import cenpy as cen
from census import Census
from us import states

acs = cenpy.products.ACS()
c = Census("771ac44f4c55670ec890af7951073be949e5130c")

# %%
datasets = list(cen.explorer.available(verbose=True).items())
datasets = pd.DataFrame(datasets, columns = ['code', 'dataset name'])

# %%
data = pd.read_csv("file.csv")
data <- read.csv("file.csv") %>% select()

# %%
datasets
# Out:
#               code                                       dataset name
# 0    c_isMicrodata  ABSCB2017          NaN
# ABSCB2018          NaN
# ...
# 1   c_isTimeseries  ABSCB2017          NaN
# ABSCB2018          NaN
# ...
# 2        publisher  ABSCB2017          U.S. Census Bureau
# ABSCB201...
# 3         temporal  ABSCB2017                NaN
# ABSCB2018        ...
# 4          spatial  ABSCB2017                    NaN
# ABSCB2018    ...
# 5      programCode  ABSCB2017          006:007
# ABSCB2018          ...
# 6         modified  ABSCB2017          2020-04-30 00:00:00.0
# ABSCB...
# 7          keyword  ABSCB2017          (census,)
# ABSCB2018        ...
# 8     contactPoint  ABSCB2017          {'fn': 'ASE Staff', 'hasEma...
# 9     distribution  ABSCB2017          {'@type': 'dcat:Distributio...
# 10     description  ABSCB2017          The Annual Business Survey ...
# 11      bureauCode  ABSCB2017          006:07
# ABSCB2018          0...
# 12     accessLevel  ABSCB2017          public
# ABSCB2018          p...
# 13           title  ABSCB2017          Economic Surveys: Annual Bu...
# 14   c_isAvailable  ABSCB2017          True
# ABSCB2018          Tru...
# 15        c_isCube  ABSCB2017           NaN
# ABSCB2018           Na...
# 16   c_isAggregate  ABSCB2017          True
# ABSCB2018          Tru...
# 17       c_dataset  ABSCB2017                      (abscb,)
# ABSCB2...
# 18         vintage  ABSCB2017          2017.0
# ABSCB2018          2...

# %%
dataset = '2021acs1'
cen.explorer.explain(dataset)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[16], line 2
#       1 dataset = '2021acs1'
# ----> 2 cen.explorer.explain(dataset)
#
# File ~/.cache/pypoetry/virtualenvs/washington-digital-equity-T8Bkn3ac-py3.11/lib/python3.11/site-packages/cenpy/explorer.py:117, in explain(identifier, verbose)
#     113     raise ValueError(
#     114         "No identifier provided. Use available() to discover identifiers"
#     115     )
#     116 elif not verbose:
# --> 117     return {APIs[identifier]["title"]: APIs[identifier]["description"]}
#     118 else:
#     119     return APIs[identifier]
#
# KeyError: '2021acs1'
